# %% [markdown]
# # 04 Clean and Validate
#
# Membersihkan artifact interim, deduplikasi review, lalu menulis output processed.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC_ROOT = PROJECT_ROOT / 'src'
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from shopee_safe_scraper.pipeline import clean_validate_artifacts

result = clean_validate_artifacts(PROJECT_ROOT)
result['summary']

# %%
result['reviews'].head()
