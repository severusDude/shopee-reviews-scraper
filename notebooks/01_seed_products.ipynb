# %% [markdown]
# # 01 Seed Products
#
# Notebook ini membuat template `seed_products.csv`. Isi URL produk Shopee secara manual dari halaman publik.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC_ROOT = PROJECT_ROOT / 'src'
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from shopee_safe_scraper.config import load_config
from shopee_safe_scraper.pipeline import build_seed_template, ensure_project_layout

paths = ensure_project_layout(PROJECT_ROOT)
config = load_config(PROJECT_ROOT / 'config.yaml')
seed_path = paths['interim'] / 'seed_products.csv'
if not seed_path.exists():
    build_seed_template(config).to_csv(seed_path, index=False)
pd.read_csv(seed_path).head(20)
# Out:
#     product_url category_quota       chosen_reason   seed_date
# 0           NaN     Elektronik  manual seed slot 1  2026-04-24
# 1           NaN     Elektronik  manual seed slot 2  2026-04-24
# 2           NaN     Elektronik  manual seed slot 3  2026-04-24
# 3           NaN     Elektronik  manual seed slot 4  2026-04-24
# 4           NaN     Elektronik  manual seed slot 5  2026-04-24
# 5           NaN     Elektronik  manual seed slot 6  2026-04-24
# 6           NaN     Elektronik  manual seed slot 7  2026-04-24
# 7           NaN     Elektronik  manual seed slot 8  2026-04-24
# 8           NaN     Elektronik  manual seed slot 9  2026-04-24
# 9           NaN        Fashion  manual seed slot 1  2026-04-24
# 10          NaN        Fashion  manual seed slot 2  2026-04-24
# 11          NaN        Fashion  manual seed slot 3  2026-04-24
# 12          NaN        Fashion  manual seed slot 4  2026-04-24
# 13          NaN        Fashion  manual seed slot 5  2026-04-24
# ...

# %% [markdown]
# ## Catatan manual seeding
#
# - Pilih produk lintas kategori.
# - Hindari mengambil dari search page secara massal.
# - Isi `chosen_reason` agar audit trail tetap jelas.
