# %% [markdown]
# # 01 Seed Products
#
# Notebook ini membuat template `seed_products.csv`. Isi URL produk Shopee secara manual dari halaman publik.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC_ROOT = PROJECT_ROOT / 'src'
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from config import load_config
from pipeline import build_seed_template, ensure_project_layout

paths = ensure_project_layout(PROJECT_ROOT)
config = load_config(PROJECT_ROOT / 'config.yaml')
seed_path = paths['interim'] / 'seed_products.csv'
if not seed_path.exists():
    build_seed_template(config).to_csv(seed_path, index=False)
pd.read_csv(seed_path).head(20)
# Out:
#                                           product_url category_quota  \
# 0   https://shopee.co.id/Lampu-Track-LED-Sorot-15W...     Elektronik
# 1   https://shopee.co.id/AQUA-Elektronik-Mesin-Cuc...     Elektronik
# 2   https://shopee.co.id/kamus-electronic-ALFALINK...     Elektronik
# 3   https://shopee.co.id/Best-Seller-HP-14-EP0321T...     Elektronik
# 4   https://shopee.co.id/%E3%80%90Best-seller%E3%8...     Elektronik
# 5   https://shopee.co.id/best-seller-hp-gaming-and...     Elektronik
# 6   https://shopee.co.id/Best-Seller-HP-14-Amd-Ryz...     Elektronik
# 7   https://shopee.co.id/Laptop-Best-Seller-Hp-14-...     Elektronik
# 8   https://shopee.co.id/BEST-SELLER-Holder-Handph...     Elektronik
# 9   https://shopee.co.id/setelan-Peace-Minus-One-S...        Fashion
# 10  https://shopee.co.id/PROMO-9.9-G29-Sepatu-Fash...        Fashion
# 11  https://shopee.co.id/fashion-wanita-best-selle...        Fashion
# 12  https://shopee.co.id/ATASAN-WANITA-FASHION-BES...        Fashion
# 13  https://shopee.co.id/MUFASA-TAS-FASHION-WANITA...        Fashion
# 14  https://shopee.co.id/GVFI-Longsleeve-Trikers-B...        Fashion
# 15  https://shopee.co.id/Hammer-Men-Polo-Striped-I...        Fashion
# 16  https://shopee.co.id/Paparos-Footwear-Slip-On-...        Fashion
# 17  https://shopee.co.id/Baju-Bangkok-Import-I-Kao...        Fashion
# 18  https://shopee.co.id/Best-Seller-Madu-TJ-Suple...      Kesehatan
# 19  https://shopee.co.id/Best-Seller-Obat-Perawata...      Kesehatan
#
#          chosen_reason   seed_date
# 0   manual seed slot 1  2026-04-24
# 1   manual seed slot 2  2026-04-24
# 2   manual seed slot 3  2026-04-24
# 3   manual seed slot 4  2026-04-24
# 4   manual seed slot 5  2026-04-24
# 5   manual seed slot 6  2026-04-24
# 6   manual seed slot 7  2026-04-24
# 7   manual seed slot 8  2026-04-24
# 8   manual seed slot 9  2026-04-24
# 9   manual seed slot 1  2026-04-24
# 10  manual seed slot 2  2026-04-24
# 11  manual seed slot 3  2026-04-24
# 12  manual seed slot 4  2026-04-24
# 13  manual seed slot 5  2026-04-24
# 14  manual seed slot 6  2026-04-24
# 15  manual seed slot 7  2026-04-24
# 16  manual seed slot 8  2026-04-24
# 17  manual seed slot 9  2026-04-24
# 18  manual seed slot 1  2026-04-24
# 19  manual seed slot 2  2026-04-24

# %% [markdown]
# ## Catatan manual seeding
#
# - Pilih produk lintas kategori.
# - Hindari mengambil dari search page secara massal.
# - Isi `chosen_reason` agar audit trail tetap jelas.
