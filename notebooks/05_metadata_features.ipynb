# %% [markdown]
# # 05 Metadata Features
#
# Membangun review-level features dan agregasi product-level untuk suspiciousness analysis tahap berikutnya.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC_ROOT = PROJECT_ROOT / 'src'
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from shopee_safe_scraper.pipeline import build_metadata_feature_artifacts

result = build_metadata_feature_artifacts(PROJECT_ROOT)
result['summary']

# %%
result['product_aggregates'].head()
