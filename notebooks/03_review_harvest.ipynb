# %% [markdown]
# # 03 Review Harvest
#
# Notebook ini memanen review dari seed product saja, memakai public page links yang bisa ditemukan dari HTML publik.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC_ROOT = PROJECT_ROOT / 'src'
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from shopee_safe_scraper.pipeline import harvest_reviews

# Notebook mode: no artificial delay, print progress so run does not look frozen.
result = harvest_reviews(PROJECT_ROOT, limit_products=3, sleep=False, max_pages_per_product=3, verbose=True)
result['summary']

# %%
result['reviews'].head()
