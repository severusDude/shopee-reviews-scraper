# %% [markdown]
# # 02 Product Snapshot
#
# Dry run disarankan pada 3 produk lebih dulu. Notebook ini membuat snapshot metadata produk dari halaman publik.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC_ROOT = PROJECT_ROOT / 'src'
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from shopee_safe_scraper.pipeline import snapshot_seed_products

result = snapshot_seed_products(PROJECT_ROOT, limit=3, sleep=True)
result['summary']
# Out:
# {'requests_made': 3, 'stop_reason': None, 'rows_written': 3}

# %%
result['products'].head()
# Out:
#     product_id                                        product_url  \
# 0  10765278201  https://shopee.co.id/Lampu-Track-LED-Sorot-15W...
# 1  43059390142  https://shopee.co.id/AQUA-Elektronik-Mesin-Cuc...
# 2     13740156  https://shopee.co.id/kamus-electronic-ALFALINK...
#
#                         scrape_time           title category_breadcrumb  \
# 0  2026-04-24T17:11:58.457212+00:00  shopee__domain                None
# 1  2026-04-24T17:12:04.088728+00:00  shopee__domain                None
# 2  2026-04-24T17:12:09.991847+00:00  shopee__domain                None
#
#   price_display discount_display sold_count_display rating_avg_display  \
# 0          None             None               None               None
# 1          None             None               None               None
# 2          None             None               None               None
#
#   rating_count_display  ... shop_url shop_location follower_count_display  \
# 0                 None  ...     None          None                   None
# 1                 None  ...     None          None                   None
# 2                 None  ...     None          None                   None
#
#   stock_display variant_summary product_description parse_status  \
# 0          None            None                None      partial
# 1          None            None                None      partial
# 2          None            None                None      partial
#
#   required_field_completeness  \
# 0                       0.444
# 1                       0.444
# 2                       0.444
#
#                                        response_hash seed_category_quota
# 0  e184ce900a68cce91658ca9c0381dd47fd7633d790adc7...          Elektronik
# 1  e184ce900a68cce91658ca9c0381dd47fd7633d790adc7...          Elektronik
# 2  e184ce900a68cce91658ca9c0381dd47fd7633d790adc7...          Elektronik
#
# [3 rows x 21 columns]
